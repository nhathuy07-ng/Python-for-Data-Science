# %% [markdown]
# ## Indexing in Pandas

# %% [markdown]
# ### **Create an index**

# %%
import pandas as pd
import numpy as np
import random

df_exams = pd.read_csv("datasets/StudentsPerformance.csv")
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# Creating non-repetitive values for the index
# Index in dataframes aren't allowed to be duplicates

new_index = np.arange(0, 1000)

# %%
# Shuffle the indices

random.shuffle(new_index)

# %%
# Create new column with new index
new_index
# Out:
# array([597, 737, 141, 781, 887, 936, 919, 458, 749, 181, 385, 498, 708,
#        553, 818, 942, 482,  95, 461, 243, 513, 510, 913, 496, 472, 179,
#        637, 652, 804, 797, 955, 547,  86, 214, 355, 801, 351, 506, 568,
#         39, 601, 160, 445,  59, 623, 888, 501, 305, 956, 326, 228,  87,
#        449, 429, 946, 215, 735, 539, 358, 234, 617, 293, 211, 198, 764,
#        741, 994, 272, 811, 576, 612, 736, 761, 753, 525, 815, 415, 678,
#        924, 342, 361, 722, 852, 972,  36, 618, 966, 407, 398, 235, 609,
#        516, 739, 468,  84,  76, 296, 814, 676, 230, 127,  56, 984, 107,
#         40, 911,  49,  10, 798, 356,  26, 219, 846, 716, 640,  12, 427,
#        519, 935, 177, 870, 891, 208, 837, 713, 309, 527, 900, 600, 346,
#        932, 985, 686, 975, 785, 649,  35, 886, 417, 239, 115, 625, 247,
#        451, 692, 548, 562, 443, 794, 284, 931, 454, 541, 664,  43, 783,
#        615, 471,  48, 826, 773, 488, 340, 509,  24, 961, 671, 304, 938,
#        163, 834, 403, 928, 278, 379, 930, 944, 847, 475, 369, 422, 180,
#        861, 650, 408, 660, 159, 394, 542, 836, 543, 651, 743, 873,  89,
#        486, 121, 796, 390, 420, 995, 812, 691,  98, 728, 614, 118, 480,
#        312, 927, 311, 227, 184, 128, 236, 433, 588, 124,  79, 633, 605,
#        646, 520, 165, 550, 168, 185,  70, 803, 641, 895,  14,  82, 564,
#        167, 657, 499, 620, 404, 740, 989,  90, 409, 808, 971, 439, 332,
#          0, 602, 175, 242, 767, 920, 339, 705, 802, 567,  67, 688, 162,
#        689, 383, 929, 144, 643, 470, 907, 897, 479, 206, 904, 999, 372,
#        507, 220, 876, 401, 265, 700,  33, 300, 835, 819, 315, 103, 867,
#        231, 493,  34, 898, 578, 276, 884, 594, 592, 536, 645,  78, 478,
#        258, 962, 654, 626,  30, 338, 474, 183, 816,  42, 694, 805, 222,
#        138, 529, 983, 997, 788, 316, 178, 328,  54, 307,   4, 226, 246,
#        405, 782, 714, 504,  47, 171, 467, 738, 866, 489, 303, 587, 434,
#        146, 457, 778, 762, 558, 579, 194, 565,  58, 289, 758, 940, 344,
#        511, 850,  71, 210, 948, 123, 477, 858, 571,  41, 918, 331,  66,
#        387, 485,  81, 882, 101, 670, 910, 441, 748, 465, 270, 666, 505,
#          2,  52, 949, 750, 981, 712, 416, 353, 195, 726, 285, 628, 418,
#        969, 786,  27, 281, 922, 828, 374, 584, 833, 572, 306, 965, 996,
#        731, 598, 595, 979, 399,  83, 376, 868, 396, 546, 774, 447, 341,
#          7, 554, 690, 392, 111, 538, 732, 150, 260,  16, 301, 549, 662,
#        412, 314, 523, 709, 659, 266, 821, 883, 771, 698, 437, 411, 787,
#        987, 624, 892, 566, 295,  63, 869, 988, 524, 807, 286, 473, 298,
#        244, 648,  44,  17,  68, 575, 426, 213, 681, 734,  20, 908, 100,
#         93, 269, 142, 540, 442, 616, 367, 438, 172, 406, 810,  57, 216,
#        916, 899, 224, 190, 725, 233,  55, 362, 683, 444, 632, 182, 800,
#        110,  29, 308, 131, 135, 599, 768,  19,  64,  73, 840, 263])

# %%
# Create new column with new index
# Same as creating new column with a given array of data

df_exams = df_exams.assign(new_index=new_index)

# Set new_index column as index
# This method creates a copy
# Can enable in_place update using inplace=True
df_exams = df_exams.set_index("new_index") # df.set_index("column name")
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 597        female        group B           bachelor's degree      standard
# 737        female        group C                some college      standard
# 141        female        group B             master's degree      standard
# 781          male        group A          associate's degree  free/reduced
# 887          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 19         female        group E             master's degree      standard
# 64           male        group C                 high school  free/reduced
# 73         female        group C                 high school  free/reduced
# 840        female        group D                some college      standard
# 263        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 597                          none          72             72             74
# 737                     completed          69             90             88
# 141                          none          90             95             93
# 781                          none          47             57             44
# 887                          none          76             78             75
# ...                           ...         ...            ...            ...
# 19                      completed          88             99             95
# 64                           none          62             55             55
# 73                      completed          59             71             65
# 840                     completed          68             78             77
# 263                          none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ### **Sort index**

# %%
# Sort dataframe by new index
# Returns new copy
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group B                 high school      standard
# 1            male        group D          associate's degree      standard
# 2          female        group D             master's degree  free/reduced
# 3          female        group A            some high school  free/reduced
# 4          female        group C                some college      standard
# ...           ...            ...                         ...           ...
# 995        female        group C          associate's degree      standard
# 996        female        group A                some college  free/reduced
# 997          male        group C                 high school      standard
# 998          male        group E          associate's degree      standard
# 999          male        group C                some college      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                       completed          58             70             68
# 1                            none          80             63             63
# 2                       completed          85             95            100
# 3                            none          59             73             69
# 4                            none          71             81             80
# ...                           ...         ...            ...            ...
# 995                     completed          67             84             86
# 996                          none          49             65             55
# 997                          none          71             66             65
# 998                          none          53             45             40
# 999                          none          58             49             42
#
# [1000 rows x 8 columns]

# %%
# Sort dataframe by new index (descending)
df_exams.sort_index(ascending=False)
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999          male        group C                some college      standard
# 998          male        group E          associate's degree      standard
# 997          male        group C                 high school      standard
# 996        female        group A                some college  free/reduced
# 995        female        group C          associate's degree      standard
# ...           ...            ...                         ...           ...
# 4          female        group C                some college      standard
# 3          female        group A            some high school  free/reduced
# 2          female        group D             master's degree  free/reduced
# 1            male        group D          associate's degree      standard
# 0          female        group B                 high school      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 999                          none          58             49             42
# 998                          none          53             45             40
# 997                          none          71             66             65
# 996                          none          49             65             55
# 995                     completed          67             84             86
# ...                           ...         ...            ...            ...
# 4                            none          71             81             80
# 3                            none          59             73             69
# 2                       completed          85             95            100
# 1                            none          80             63             63
# 0                       completed          58             70             68
#
# [1000 rows x 8 columns]
